# %% [markdown]
# ### Run the next cell to improt SupraMolSim and required dependencies

# %%
import supramolsim

# %% [markdown]
# # Set configuration directory
#
# ### Select "Use Demos" to access preset models provided with the package
# ### Optionally, copy and paste the full path to your custom directory for configuration files
#
# ### After clicking on your prefered configuration source you will
# ### see the full path of the configuration files

# %%
supramolsim.set_directory()
# Out:
# VBox(children=(Textarea(value='', layout=Layout(width='50%'), style=TextStyle(description_width='initial')), B…
# ['/Users/damianmartinez/Documents/AIOCB/Code/SupraMolecularSimulator/src/supramolsim/configuration']

# %% [markdown]
# # Select the structure you want to model
#
# ## Run the next cell and select your structure.
# ## To change between option 1 and 2 run the cell again.
#
# ## Option 1:
# #### Click on "Load from demo structures" to
# #### show a dropdown menu from which you can select a structure
# #### based on its atomic model.
#
# ### Then, click "Load Structure" to start parsing your structure
#
# ## Option 2
# #### Click on "Upload CIF file". Then click on "Select" and
# #### browse your directories to locate the CIF file you wish to
# #### upload. Once you locate your file, click again in "Select", then
# #### "Load from file" to load and parse your local CIF file.

# %% [markdown]
# ## Loading a structure might take a few seconds, depending on the size of the file

# %%
supramolsim.select_structure()
# Out:
# Dropdown(layout=Layout(width='50%'), options=('7R5K: Human nuclear pore complex (constricted)', '2RCJ: Solutio…
# Button(description='Load structure', layout=Layout(width='50%'), style=ButtonStyle())
# FloatSlider(value=0.01, description='Fraction of total atoms to show', disabled=True, layout=Layout(width='50%…
# Button(description='Show structure', disabled=True, layout=Layout(width='50%'), style=ButtonStyle())
# Checkbox(value=True, description='Hide plot grids', disabled=True, layout=Layout(width='50%'), style=CheckboxS…
# Loading structure.
# Downloading 7R5K...
# 7R5K.cif: 63.2MiB [00:26, 2.47MiB/s]
# Parsing structure. This might take a few seconds...
# Building structure for: 7R5K: Human nuclear pore complex (constricted)...
# Structure Loaded!

# %%
supramolsim.create_structural_model()

# %%
supramolsim.refine_structural_model()

# %%
supramolsim.create_field()

# %%
supramolsim.set_image_modalities()

# %%
supramolsim.set_acq_params()

# %%
supramolsim.run_simulation()
