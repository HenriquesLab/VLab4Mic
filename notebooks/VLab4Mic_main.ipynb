# %% [markdown]
# # VLab4Mic: a universal validation tool for microscopy.
#
# ## VLab4Mic is a modular package where you can:
# - Model labelling strategies of macromolecular complexes
# - Simulate image acquisitions under diverse microscopy modalities
# - Find optimal parameters for feature recovery

# %% [markdown]
# # Choose a structure and a probe
# ##### Click on "Generate labelled particle" to use the current probe to label the structure and show a preview of their combination

# %%
from supramolsim.jupyter_widgets import sweep_widgets
vlab_ui = sweep_widgets.Sweep_gui()
vlab_ui.structure_probe_ui(height="600px")

# %% [markdown]
# # Create a virtual sample and set the imaging modalities
#
# ##### Use the right panel to define the number of particles and parameters of the virtual sample. <br> The panel in the middle shows you a preview of the imaging modality you can chose to image your virtual sample. <br> Click on "Preview acquisition" in left panel to get a preview of your current sample imaged with the current modality in preview.
#
# #####  If you want to keep this modality and acquisition parmeters, click on "Set parameters of preview".

# %%
vlab_ui.vsample_vmicroscope_ui(height="600px")

# %% [markdown]
# # Run your simulation
#
# ### Set a name for your experiment, change the output directory if necessary and click on "Run simulation"

# %%
vlab_ui.acquire_images()
